# %%
from alpaca.trading.client import TradingClient
from alpaca.trading.requests import GetOrdersRequest
from alpaca.trading.enums import QueryOrderStatus
from datetime import datetime
import pandas as pd
import configparser


# Read the config file
config = configparser.ConfigParser()
config.read("../alpaca.ini")
api = config['ALPACA']['api']
secret = config['ALPACA']['secret']


file_name = datetime.now().strftime("%Y_%m_%d_%H_%M_%S") + ("_order_history.csv")
file_name = "orders_data/" + file_name

# %%
trading_client = TradingClient(api, secret)

# Get the last 100 closed orders
get_orders_data = GetOrdersRequest(
    status=QueryOrderStatus.ALL,
    limit=10000,
    nested=True  # show nested multi-leg orders
)

all_orders = trading_client.get_orders(filter=get_orders_data)

all_orders_df = pd.DataFrame({
    'ticker':[x.symbol for x in all_orders],
    'side':[x.side for x in all_orders],
    'filled_qty':[x.filled_qty for x in all_orders],
    'filled_avg_price':[x.filled_avg_price for x in all_orders],
    'limit_price':[x.limit_price for x in all_orders],
    'order_type':[x.order_type for x in all_orders],
    'status':[x.status for x in all_orders],
    'stop_price':[x.stop_price for x in all_orders],
    'created_at':[x.created_at for x in all_orders],
    'filled_at':[x.filled_at for x in all_orders],
    'client_order_id':[x.client_order_id for x in all_orders]
})

# %%
all_orders_df.to_csv(file_name, index = False)

# %%
all_orders
# Out:
# [{   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#      'canceled_at': None,
#      'client_order_id': '3bce5f15-b0b6-4bf6-8511-164ce4d43079',
#      'created_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 249023, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 422605, tzinfo=TzInfo(UTC)),
#      'filled_avg_price': '592.79',
#      'filled_qty': '600',
#      'hwm': None,
#      'id': UUID('b3ae45a6-afa5-471a-8dbf-70951a1b65c5'),
#      'legs': [   {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                      'canceled_at': None,
#                      'client_order_id': 'b5facfa5-fcf3-454b-a411-bb819d3dcef6',
#                      'created_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 249023, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('76fd238c-4f82-4492-8806-3186b7b61d67'),
#                      'legs': None,
#                      'limit_price': '480',
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.LIMIT: 'limit'>,
#                      'qty': '600',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.BUY: 'buy'>,
#                      'status': <OrderStatus.NEW: 'new'>,
#                      'stop_price': None,
#                      'submitted_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 438846, tzinfo=TzInfo(UTC)),
#                      'symbol': 'SPY',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.LIMIT: 'limit'>,
#                      'updated_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 439734, tzinfo=TzInfo(UTC))},
#                  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                      'canceled_at': None,
#                      'client_order_id': 'daa478b6-759f-42ed-9158-46bba28551a2',
#                      'created_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 249023, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('14e57528-45db-42ec-ab25-223d7f71b167'),
#                      'legs': None,
#                      'limit_price': None,
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.STOP: 'stop'>,
#                      'qty': '600',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.BUY: 'buy'>,
#                      'status': <OrderStatus.HELD: 'held'>,
#                      'stop_price': '608',
#                      'submitted_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 249023, tzinfo=TzInfo(UTC)),
#                      'symbol': 'SPY',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.STOP: 'stop'>,
#                      'updated_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 250954, tzinfo=TzInfo(UTC))}],
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.BRACKET: 'bracket'>,
#      'order_type': <OrderType.MARKET: 'market'>,
#      'qty': '600',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.SELL: 'sell'>,
#      'status': <OrderStatus.FILLED: 'filled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 254994, tzinfo=TzInfo(UTC)),
#      'symbol': 'SPY',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.MARKET: 'market'>,
#      'updated_at': datetime.datetime(2024, 12, 20, 16, 34, 41, 424250, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#      'canceled_at': None,
#      'client_order_id': '40b7b580-b64c-4d4e-acbf-7d9fbb0db704',
#      'created_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 4872, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 373165, tzinfo=TzInfo(UTC)),
#      'filled_avg_price': '590.37',
#      'filled_qty': '600',
#      'hwm': None,
#      'id': UUID('23f6a91d-a367-4789-9082-fbb1f723ff7e'),
#      'legs': [   {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                      'canceled_at': None,
#                      'client_order_id': '3c7afff9-729d-49ba-94c5-fc91c4561430',
#                      'created_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 4872, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('a8ba4526-9b23-45ca-9e52-0b6985302891'),
#                      'legs': None,
#                      'limit_price': '480',
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.LIMIT: 'limit'>,
#                      'qty': '600',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.BUY: 'buy'>,
#                      'status': <OrderStatus.NEW: 'new'>,
#                      'stop_price': None,
#                      'submitted_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 379012, tzinfo=TzInfo(UTC)),
#                      'symbol': 'SPY',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.LIMIT: 'limit'>,
#                      'updated_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 380012, tzinfo=TzInfo(UTC))},
#                  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('b28f4066-5c6d-479b-a2af-85dc1a8f16fb'),
#                      'canceled_at': None,
#                      'client_order_id': 'e9f329e3-425c-43a6-9c4a-cb1ffa431cbf',
#                      'created_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 4872, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('a2aea654-57c0-46ab-b2a0-5e16457d5286'),
#                      'legs': None,
#                      'limit_price': None,
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.STOP: 'stop'>,
#                      'qty': '600',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.BUY: 'buy'>,
#                      'status': <OrderStatus.HELD: 'held'>,
#                      'stop_price': '608',
#                      'submitted_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 4872, tzinfo=TzInfo(UTC)),
#                      'symbol': 'SPY',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.STOP: 'stop'>,
#                      'updated_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 6504, tzinfo=TzInfo(UTC))}],
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.BRACKET: 'bracket'>,
#      'order_type': <OrderType.MARKET: 'market'>,
#      'qty': '600',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.SELL: 'sell'>,
#      'status': <OrderStatus.FILLED: 'filled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 9835, tzinfo=TzInfo(UTC)),
#      'symbol': 'SPY',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.MARKET: 'market'>,
#      'updated_at': datetime.datetime(2024, 12, 19, 15, 16, 58, 375129, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('c8899fc1-c3b2-411c-a940-4b9380a09b84'),
#      'canceled_at': None,
#      'client_order_id': '038295d4-ac63-41e1-9139-aaf4a68488b9',
#      'created_at': datetime.datetime(2024, 12, 18, 15, 18, 11, 467619, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': datetime.datetime(2024, 12, 18, 15, 18, 12, 48048, tzinfo=TzInfo(UTC)),
#      'filled_avg_price': '11.24',
#      'filled_qty': '2500',
#      'hwm': None,
#      'id': UUID('45ad00d3-0811-40e4-8fd1-d850d8203ecc'),
#      'legs': [   {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('c8899fc1-c3b2-411c-a940-4b9380a09b84'),
#                      'canceled_at': None,
#                      'client_order_id': 'c13a0da3-a04f-4f4a-920a-f46a7342141d',
#                      'created_at': datetime.datetime(2024, 12, 18, 15, 18, 11, 467619, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('2c05f7ce-f656-43d9-b00c-e3ee862cfc39'),
#                      'legs': None,
#                      'limit_price': '16.45',
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.LIMIT: 'limit'>,
#                      'qty': '2500',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.NEW: 'new'>,
#                      'stop_price': None,
#                      'submitted_at': datetime.datetime(2024, 12, 18, 15, 18, 12, 57197, tzinfo=TzInfo(UTC)),
#                      'symbol': 'WBD',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.LIMIT: 'limit'>,
#                      'updated_at': datetime.datetime(2024, 12, 18, 15, 18, 12, 58097, tzinfo=TzInfo(UTC))},
#                  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('c8899fc1-c3b2-411c-a940-4b9380a09b84'),
#                      'canceled_at': None,
#                      'client_order_id': '48e39e18-1c0a-4122-a2cc-8eca1235ca4d',
#                      'created_at': datetime.datetime(2024, 12, 18, 15, 18, 11, 467619, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('ebab58be-5022-47a9-bdc7-cd9bfb7aea3c'),
#                      'legs': None,
#                      'limit_price': None,
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.STOP: 'stop'>,
#                      'qty': '2500',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.HELD: 'held'>,
#                      'stop_price': '9.22',
#                      'submitted_at': datetime.datetime(2024, 12, 18, 15, 18, 11, 467619, tzinfo=TzInfo(UTC)),
#                      'symbol': 'WBD',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.STOP: 'stop'>,
#                      'updated_at': datetime.datetime(2024, 12, 18, 15, 18, 11, 469257, tzinfo=TzInfo(UTC))}],
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.BRACKET: 'bracket'>,
#      'order_type': <OrderType.MARKET: 'market'>,
#      'qty': '2500',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.FILLED: 'filled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 12, 18, 15, 18, 11, 473369, tzinfo=TzInfo(UTC)),
#      'symbol': 'WBD',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.MARKET: 'market'>,
#      'updated_at': datetime.datetime(2024, 12, 18, 15, 18, 12, 49933, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('9f45f86e-282a-4d47-9d6c-b0ff18fa32c6'),
#      'canceled_at': None,
#      'client_order_id': '3163227c-79c9-4ef5-b8da-97197e6bd48f',
#      'created_at': datetime.datetime(2024, 12, 16, 14, 57, 6, 728475, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': datetime.datetime(2024, 12, 16, 14, 57, 6, 998627, tzinfo=TzInfo(UTC)),
#      'filled_avg_price': '94.13',
#      'filled_qty': '1500',
#      'hwm': None,
#      'id': UUID('74839c85-f7f9-4b21-a682-6d555f17dc0e'),
#      'legs': [   {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('9f45f86e-282a-4d47-9d6c-b0ff18fa32c6'),
#                      'canceled_at': datetime.datetime(2024, 12, 18, 19, 28, 56, 986851, tzinfo=TzInfo(UTC)),
#                      'client_order_id': 'adfa9d43-cdc7-4703-8b10-7252e560941b',
#                      'created_at': datetime.datetime(2024, 12, 16, 14, 57, 6, 728475, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('96ae005a-6cad-4181-9ddd-9febc7fda197'),
#                      'legs': None,
#                      'limit_price': '115.42',
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.LIMIT: 'limit'>,
#                      'qty': '1500',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.CANCELED: 'canceled'>,
#                      'stop_price': None,
#                      'submitted_at': datetime.datetime(2024, 12, 16, 14, 57, 7, 4591, tzinfo=TzInfo(UTC)),
#                      'symbol': 'VNQ',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.LIMIT: 'limit'>,
#                      'updated_at': datetime.datetime(2024, 12, 18, 19, 28, 56, 988449, tzinfo=TzInfo(UTC))},
#                  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('9f45f86e-282a-4d47-9d6c-b0ff18fa32c6'),
#                      'canceled_at': None,
#                      'client_order_id': '3c1b6b2c-8030-42ed-b378-b52919924322',
#                      'created_at': datetime.datetime(2024, 12, 16, 14, 57, 6, 728475, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': datetime.datetime(2024, 12, 18, 19, 28, 57, 870567, tzinfo=TzInfo(UTC)),
#                      'filled_avg_price': '91.18',
#                      'filled_qty': '1500',
#                      'hwm': None,
#                      'id': UUID('eab7c7eb-a0fa-4b7c-adf3-01b5c57ad9d4'),
#                      'legs': None,
#                      'limit_price': None,
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.STOP: 'stop'>,
#                      'qty': '1500',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.FILLED: 'filled'>,
#                      'stop_price': '91.19',
#                      'submitted_at': datetime.datetime(2024, 12, 18, 19, 28, 56, 992476, tzinfo=TzInfo(UTC)),
#                      'symbol': 'VNQ',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.STOP: 'stop'>,
#                      'updated_at': datetime.datetime(2024, 12, 18, 19, 28, 57, 872494, tzinfo=TzInfo(UTC))}],
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.BRACKET: 'bracket'>,
#      'order_type': <OrderType.MARKET: 'market'>,
#      'qty': '1500',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.FILLED: 'filled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 12, 16, 14, 57, 6, 736073, tzinfo=TzInfo(UTC)),
#      'symbol': 'VNQ',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.MARKET: 'market'>,
#      'updated_at': datetime.datetime(2024, 12, 16, 14, 57, 7, 112, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('e7535ed9-c182-41ef-80f6-ee08f4166b6c'),
#      'canceled_at': None,
#      'client_order_id': '183f75e6-3ea1-40ed-9b45-69e61ca4289e',
#      'created_at': datetime.datetime(2024, 12, 12, 16, 25, 56, 638061, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': datetime.datetime(2024, 12, 12, 16, 25, 57, 583031, tzinfo=TzInfo(UTC)),
#      'filled_avg_price': '382.92',
#      'filled_qty': '250',
#      'hwm': None,
#      'id': UUID('e31fc42a-79ae-481f-bc66-38e069657565'),
#      'legs': [   {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('e7535ed9-c182-41ef-80f6-ee08f4166b6c'),
#                      'canceled_at': datetime.datetime(2024, 12, 19, 15, 35, 42, 192690, tzinfo=TzInfo(UTC)),
#                      'client_order_id': 'ff528b33-c296-42c3-9105-2c4766b66583',
#                      'created_at': datetime.datetime(2024, 12, 12, 16, 25, 56, 638061, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('450c1a0e-eec8-41cc-bce5-d8265cf7cf40'),
#                      'legs': None,
#                      'limit_price': '417',
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.LIMIT: 'limit'>,
#                      'qty': '250',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.CANCELED: 'canceled'>,
#                      'stop_price': None,
#                      'submitted_at': datetime.datetime(2024, 12, 12, 16, 25, 57, 604214, tzinfo=TzInfo(UTC)),
#                      'symbol': 'CAT',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.LIMIT: 'limit'>,
#                      'updated_at': datetime.datetime(2024, 12, 19, 15, 35, 42, 194347, tzinfo=TzInfo(UTC))},
#                  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('e7535ed9-c182-41ef-80f6-ee08f4166b6c'),
#                      'canceled_at': None,
#                      'client_order_id': '18294787-a026-4aad-8f24-b0dc5fa06d1b',
#                      'created_at': datetime.datetime(2024, 12, 12, 16, 25, 56, 638061, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': datetime.datetime(2024, 12, 19, 15, 35, 43, 622260, tzinfo=TzInfo(UTC)),
#                      'filled_avg_price': '362.02',
#                      'filled_qty': '250',
#                      'hwm': None,
#                      'id': UUID('19fb476c-f93a-44f6-b48a-5301f1b9e2fc'),
#                      'legs': None,
#                      'limit_price': None,
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.STOP: 'stop'>,
#                      'qty': '250',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.FILLED: 'filled'>,
#                      'stop_price': '362.25',
#                      'submitted_at': datetime.datetime(2024, 12, 19, 15, 35, 42, 198149, tzinfo=TzInfo(UTC)),
#                      'symbol': 'CAT',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.STOP: 'stop'>,
#                      'updated_at': datetime.datetime(2024, 12, 19, 15, 35, 43, 623845, tzinfo=TzInfo(UTC))}],
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.BRACKET: 'bracket'>,
#      'order_type': <OrderType.MARKET: 'market'>,
#      'qty': '250',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.FILLED: 'filled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 12, 12, 16, 25, 56, 642515, tzinfo=TzInfo(UTC)),
#      'symbol': 'CAT',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.MARKET: 'market'>,
#      'updated_at': datetime.datetime(2024, 12, 12, 16, 25, 57, 584711, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('d2cb3472-a97f-4434-9736-c4ca7f82a67f'),
#      'canceled_at': None,
#      'client_order_id': 'a23233dd-9582-45de-891b-2e64b04be6d5',
#      'created_at': datetime.datetime(2024, 12, 12, 15, 51, 30, 556302, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': datetime.datetime(2024, 12, 12, 15, 52, 33, 272134, tzinfo=TzInfo(UTC)),
#      'filled_avg_price': '367.13',
#      'filled_qty': '100',
#      'hwm': None,
#      'id': UUID('b18fad64-eb7b-4628-8051-12fccf1c6532'),
#      'legs': [   {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('d2cb3472-a97f-4434-9736-c4ca7f82a67f'),
#                      'canceled_at': datetime.datetime(2024, 12, 13, 14, 30, 40, 622182, tzinfo=TzInfo(UTC)),
#                      'client_order_id': 'f73aa3cb-319d-4087-88ab-c189a8d8d829',
#                      'created_at': datetime.datetime(2024, 12, 12, 15, 51, 30, 556302, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('38dca7ce-5d38-416d-aebf-203bde92ae4e'),
#                      'legs': None,
#                      'limit_price': '400',
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.LIMIT: 'limit'>,
#                      'qty': '100',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.CANCELED: 'canceled'>,
#                      'stop_price': None,
#                      'submitted_at': datetime.datetime(2024, 12, 12, 15, 52, 33, 287910, tzinfo=TzInfo(UTC)),
#                      'symbol': 'SHW',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.LIMIT: 'limit'>,
#                      'updated_at': datetime.datetime(2024, 12, 13, 14, 30, 40, 623521, tzinfo=TzInfo(UTC))},
#                  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('d2cb3472-a97f-4434-9736-c4ca7f82a67f'),
#                      'canceled_at': None,
#                      'client_order_id': '5f298adf-8c6d-44e2-93ce-5b66f2ec54b8',
#                      'created_at': datetime.datetime(2024, 12, 12, 15, 51, 30, 556302, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': datetime.datetime(2024, 12, 13, 14, 30, 40, 919318, tzinfo=TzInfo(UTC)),
#                      'filled_avg_price': '365.28',
#                      'filled_qty': '100',
#                      'hwm': None,
#                      'id': UUID('66629681-c146-44c2-bb09-fb68de844031'),
#                      'legs': None,
#                      'limit_price': None,
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.STOP: 'stop'>,
#                      'qty': '100',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.FILLED: 'filled'>,
#                      'stop_price': '365.77',
#                      'submitted_at': datetime.datetime(2024, 12, 13, 14, 30, 40, 628823, tzinfo=TzInfo(UTC)),
#                      'symbol': 'SHW',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.STOP: 'stop'>,
#                      'updated_at': datetime.datetime(2024, 12, 13, 14, 30, 40, 920886, tzinfo=TzInfo(UTC))}],
#      'limit_price': '367.26',
#      'notional': None,
#      'order_class': <OrderClass.BRACKET: 'bracket'>,
#      'order_type': <OrderType.LIMIT: 'limit'>,
#      'qty': '100',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.FILLED: 'filled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 12, 12, 15, 51, 30, 565841, tzinfo=TzInfo(UTC)),
#      'symbol': 'SHW',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.LIMIT: 'limit'>,
#      'updated_at': datetime.datetime(2024, 12, 12, 15, 52, 33, 273803, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('d2cb3472-a97f-4434-9736-c4ca7f82a67f'),
#      'canceled_at': datetime.datetime(2024, 12, 12, 16, 47, 2, 638563, tzinfo=TzInfo(UTC)),
#      'client_order_id': '3965a7c9-65fb-4b42-8e8d-d891d4350bb4',
#      'created_at': datetime.datetime(2024, 12, 12, 15, 47, 2, 977737, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('ece735ef-ed50-49fa-8ac2-54824ad9766d'),
#      'legs': [   {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('d2cb3472-a97f-4434-9736-c4ca7f82a67f'),
#                      'canceled_at': datetime.datetime(2024, 12, 12, 16, 47, 2, 640329, tzinfo=TzInfo(UTC)),
#                      'client_order_id': '6d4ef110-55d6-41cb-8242-b0b21196f047',
#                      'created_at': datetime.datetime(2024, 12, 12, 15, 47, 2, 977737, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('868ca4ef-5bca-49bb-a530-10c7ca99a16e'),
#                      'legs': None,
#                      'limit_price': '400',
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.LIMIT: 'limit'>,
#                      'qty': '300',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.CANCELED: 'canceled'>,
#                      'stop_price': None,
#                      'submitted_at': datetime.datetime(2024, 12, 12, 15, 47, 2, 977737, tzinfo=TzInfo(UTC)),
#                      'symbol': 'SHW',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.LIMIT: 'limit'>,
#                      'updated_at': datetime.datetime(2024, 12, 12, 16, 47, 2, 640330, tzinfo=TzInfo(UTC))},
#                  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#                      'asset_id': UUID('d2cb3472-a97f-4434-9736-c4ca7f82a67f'),
#                      'canceled_at': datetime.datetime(2024, 12, 12, 16, 47, 2, 640357, tzinfo=TzInfo(UTC)),
#                      'client_order_id': 'b3de62c1-ec07-4fe8-810e-2e6ac16660ca',
#                      'created_at': datetime.datetime(2024, 12, 12, 15, 47, 2, 977737, tzinfo=TzInfo(UTC)),
#                      'expired_at': None,
#                      'extended_hours': False,
#                      'failed_at': None,
#                      'filled_at': None,
#                      'filled_avg_price': None,
#                      'filled_qty': '0',
#                      'hwm': None,
#                      'id': UUID('9425b48d-20a1-47e3-ab53-fe89e1840204'),
#                      'legs': None,
#                      'limit_price': None,
#                      'notional': None,
#                      'order_class': <OrderClass.BRACKET: 'bracket'>,
#                      'order_type': <OrderType.STOP: 'stop'>,
#                      'qty': '300',
#                      'replaced_at': None,
#                      'replaced_by': None,
#                      'replaces': None,
#                      'side': <OrderSide.SELL: 'sell'>,
#                      'status': <OrderStatus.CANCELED: 'canceled'>,
#                      'stop_price': '341.08',
#                      'submitted_at': datetime.datetime(2024, 12, 12, 15, 47, 2, 977737, tzinfo=TzInfo(UTC)),
#                      'symbol': 'SHW',
#                      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#                      'trail_percent': None,
#                      'trail_price': None,
#                      'type': <OrderType.STOP: 'stop'>,
#                      'updated_at': datetime.datetime(2024, 12, 12, 16, 47, 2, 640358, tzinfo=TzInfo(UTC))}],
#      'limit_price': '354.86',
#      'notional': None,
#      'order_class': <OrderClass.BRACKET: 'bracket'>,
#      'order_type': <OrderType.LIMIT: 'limit'>,
#      'qty': '300',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.CANCELED: 'canceled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 12, 12, 15, 47, 2, 982573, tzinfo=TzInfo(UTC)),
#      'symbol': 'SHW',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.LIMIT: 'limit'>,
#      'updated_at': datetime.datetime(2024, 12, 12, 16, 47, 2, 640269, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('88968dd4-f4b4-4143-830e-f5ed16a4d241'),
#      'canceled_at': None,
#      'client_order_id': '6a5f5341-5dd7-47fa-93bc-1fdc4c66e910',
#      'created_at': datetime.datetime(2024, 12, 11, 20, 2, 16, 191966, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': None,
#      'filled_avg_price': None,
#      'filled_qty': '0',
#      'hwm': None,
#      'id': UUID('98532612-2785-43a7-9c58-a27a804aa8c0'),
#      'legs': None,
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.STOP: 'stop'>,
#      'qty': '1200',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.SELL: 'sell'>,
#      'status': <OrderStatus.NEW: 'new'>,
#      'stop_price': '41.88',
#      'submitted_at': datetime.datetime(2024, 12, 11, 20, 2, 16, 195943, tzinfo=TzInfo(UTC)),
#      'symbol': 'IOT',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.STOP: 'stop'>,
#      'updated_at': datetime.datetime(2024, 12, 11, 20, 2, 16, 197072, tzinfo=TzInfo(UTC))},
#  {   'asset_class': <AssetClass.US_EQUITY: 'us_equity'>,
#      'asset_id': UUID('88968dd4-f4b4-4143-830e-f5ed16a4d241'),
#      'canceled_at': None,
#      'client_order_id': 'ccc927ce-a368-4d8e-8f44-020721c5cca4',
#      'created_at': datetime.datetime(2024, 12, 11, 19, 56, 6, 882974, tzinfo=TzInfo(UTC)),
#      'expired_at': None,
#      'extended_hours': False,
#      'failed_at': None,
#      'filled_at': datetime.datetime(2024, 12, 11, 19, 56, 7, 475631, tzinfo=TzInfo(UTC)),
#      'filled_avg_price': '46.01',
#      'filled_qty': '1200',
#      'hwm': None,
#      'id': UUID('96f44d62-9cd6-4713-ab75-89b9d63ff086'),
#      'legs': None,
#      'limit_price': None,
#      'notional': None,
#      'order_class': <OrderClass.SIMPLE: 'simple'>,
#      'order_type': <OrderType.MARKET: 'market'>,
#      'qty': '1200',
#      'replaced_at': None,
#      'replaced_by': None,
#      'replaces': None,
#      'side': <OrderSide.BUY: 'buy'>,
#      'status': <OrderStatus.FILLED: 'filled'>,
#      'stop_price': None,
#      'submitted_at': datetime.datetime(2024, 12, 11, 19, 56, 6, 910197, tzinfo=TzInfo(UTC)),
#      'symbol': 'IOT',
#      'time_in_force': <TimeInForce.GTC: 'gtc'>,
#      'trail_percent': None,
#      'trail_price': None,
#      'type': <OrderType.MARKET: 'market'>,
#      'updated_at': datetime.datetime(2024, 12, 11, 19, 56, 7, 477540, tzinfo=TzInfo(UTC))}]
