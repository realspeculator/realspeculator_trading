# %% [markdown]
# ### January 2, 2024

# %% [markdown]
# The start of a new trading day of a new trading year. This will determine where the S&P 500 open will print the first tick.

# %% [markdown]
# #### 9:21AM
#
# As of this time we are opeing within the trading range from Dec 31, 2024
#
# ![image.png](attachment:e54620d6-2def-40e7-93fa-b7a0383cde7f.png)
