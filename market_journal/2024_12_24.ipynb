# %% [markdown]
# ### December 24, 2024
#
# The day before Christmas holiday.

# %% [markdown]
# Since this is a day before major holiday today we will try and identify potential stock investments that we can make in 2025.
#
# The short position is very close to getting invalidated. The ES futures are now trading at 6044 and very close to the 6050 level which is a key pivotal level. A decisive break above 6050 could see the ES rally another 100 or so points to ATH level.

# %% [markdown]
# ![image.png](attachment:9d1ede9c-9364-465a-8f60-81fee9589364.png)
